# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %matplotlib inline
table  = pd.read_csv(r"D:\Lectures\England\DAV\Report\dataset\app_usage\running_app_u01.csv")

#table[['timestamp']].head()
#for row in table.iterrows():
#    table['timestamp'] = table['timestamp'].replace(row[1][2],datetime.fromtimestamp(row[1][2]))

# %%
table.columns
# Out:
# Index(['id', 'device', 'timestamp', 'RUNNING_TASKS_baseActivity_mClass',
#        'RUNNING_TASKS_baseActivity_mPackage', 'RUNNING_TASKS_id',
#        'RUNNING_TASKS_numActivities', 'RUNNING_TASKS_numRunning',
#        'RUNNING_TASKS_topActivity_mClass',
#        'RUNNING_TASKS_topActivity_mPackage'],
#       dtype='object')

# %%
temp = table[['timestamp','RUNNING_TASKS_baseActivity_mPackage']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1fbc461769c0> in <module>
# ----> 1 temp = table[['timestamp','RUNNING_TASKS_baseActivity_mPackage']]
#
# NameError: name 'table' is not defined

# %%
#for row in temp.iterrows():
    #print(row[1][0])
    #temp['timestamp'] = temp['timestamp'].replace(row[1][0],datetime.fromtimestamp(row[1][0]))

# %%
temp
# Out:
#         timestamp      RUNNING_TASKS_baseActivity_mPackage
# 0      1364341060                            org.bewellapp
# 1      1364341060                     com.android.launcher
# 2      1364341060             com.google.android.apps.paco
# 3      1364341060                       com.android.chrome
# 4      1364341060  com.google.android.googlequicksearchbox
# ...           ...                                      ...
# 59237  1370887966                     com.android.settings
# 59238  1370889166                     com.android.launcher
# 59239  1370889166                    com.android.deskclock
# 59240  1370889166                          com.android.mms
# 59241  1370889166                     com.android.settings
#
# [59242 rows x 2 columns]

# %% [markdown]
# u1=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u2=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u3=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u4=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u5=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u6=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u8=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u9=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u10=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u11=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u13=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u14=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u15=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u16=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u17=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u18=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u19=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u20=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u21=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u23=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u24=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u25=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u26=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u28=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u31=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u32=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u33=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u34=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u35=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u36=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u37=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u40=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u42=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u43=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u44=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u45=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u46=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u47=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u48=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u50=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u51=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u52=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u53=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u54=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u55=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u57=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u58=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u59=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %% [markdown]
# u60=temp.RUNNING_TASKS_baseActivity_mPackage.unique().tolist()

# %%
user_list = []
for i in range (61):
    if(i==0 or i==7 or i==12 or i==22 or i==27 or i==29 or i==30 or i==38 or i==39 or i==41 or i==49 or i==56):
        continue
    else:
        user_list.append("User "+str(i))

# %% [markdown]
# df = pd.DataFrame(data=[u1,u2,u3,u4,u5,u6,u8,u9,u10,u11,u13,u14,u15,u16,u17,u18,u19,u20,u21,u23,u24,u25,u26,u28,u31,u32,u33,u34,u35,u36,u37,u40,u42,u43,u44,u45,u46,u47,u48,u50,u51,u52,u53,u54,u55,u57,u58,u59,u60])

# %%
df.columns = user_list

# %%
for foo in range(119):
    print (df['User 14'][foo])
# Out:
# com.android.launcher
# com.android.vending
# com.myzeo.android
# com.android.settings
# com.android.chrome
# com.google.android.apps.paco
# com.google.android.gm
# com.android.systemui
# com.google.android.googlequicksearchbox
# com.google.android.youtube
# com.android.contacts
# org.bewellapp
# com.jawbone.up
# com.google.android.gallery3d
# edu.dartmouth.cs.layouts
# com.google.android.deskclock
# com.sina.weibo
# com.android.mms
# com.android.phone
# edu.dartmouth.cs.myruns
# edu.dartmouth.cs.myruns2
# edu.dartmouth.cs.actiontabs
# edu.cs.dartmouth.lab1
# com.example.myruns
# edu.cs.dartmouth.myruns
# edu.dartmouth.cs.lab1
# com.blanchet.julien.cs65.hw1
# com.infonow.bofa
# com.google.android.talk
# com.example.edu.dartmouth.cs.myruns2
# edu.dartmouth.cs.camera
# com.google.android.gsf.login
# com.paad.DatabaseSkeleton
# cs.dartmouth.edu.myruns1
# edu.dartmouth.cs.myruns3
# com.google.android.apps.walletnfcrel
# edu.dartmouth.cs.myruns4
# edu.dartmouth.cs.test
# com.paad.whereami
# ...

# %%
temp['RUNNING_TASKS_baseActivity_mPackage'].value_counts().to_csv('abc52.csv')

# %%
df
# Out:
#                            User 1                        User 2  \
# 0           com.google.android.gm  com.google.android.apps.paco
# 1            com.android.launcher          com.android.launcher
# 2                  com.rhmsoft.fm         com.google.android.gm
# 3            com.android.systemui          com.android.settings
# 4    com.google.android.apps.paco            com.android.chrome
# ..                            ...                           ...
# 114                          None                          None
# 115                          None                          None
# 116                          None                          None
# 117                          None                          None
# 118                          None                          None
#
#                            User 3                          User 4  \
# 0    com.google.android.apps.paco    com.google.android.apps.paco
# ...

# %%
app_use  = pd.read_csv(r"C:\Users\muhad\DAV\app_use.csv")
app_use
# Out:
#      Unnamed: 0                        User 1                        User 2  \
# 0             0         com.google.android.gm  com.google.android.apps.paco
# 1             1          com.android.launcher          com.android.launcher
# 2             2                com.rhmsoft.fm         com.google.android.gm
# 3             3          com.android.systemui          com.android.settings
# 4             4  com.google.android.apps.paco            com.android.chrome
# ..          ...                           ...                           ...
# 114         114                           NaN                           NaN
# 115         115                           NaN                           NaN
# 116         116                           NaN                           NaN
# 117         117                           NaN                           NaN
# 118         118                           NaN                           NaN
#
# ...

# %%
table  = pd.read_csv(r"D:\Lectures\England\DAV\Report\dataset\app_usage\running_app_u53.csv")
table.head()
# Out:
#                                         id  \
# 0  7e631eef-68e6-4f68-8d87-fa3bf6de1552-18
# 1  7e631eef-68e6-4f68-8d87-fa3bf6de1552-18
# 2  7e631eef-68e6-4f68-8d87-fa3bf6de1552-18
# 3  7e631eef-68e6-4f68-8d87-fa3bf6de1552-18
# 4  7e631eef-68e6-4f68-8d87-fa3bf6de1552-18
#
#                                  device   timestamp  \
# 0  75c1cf2f-1302-4792-abaa-8aa878e7dbb8  1364102946
# 1  75c1cf2f-1302-4792-abaa-8aa878e7dbb8  1364102946
# 2  75c1cf2f-1302-4792-abaa-8aa878e7dbb8  1364102946
# 3  75c1cf2f-1302-4792-abaa-8aa878e7dbb8  1364102946
# 4  75c1cf2f-1302-4792-abaa-8aa878e7dbb8  1364102946
#
#                    RUNNING_TASKS_baseActivity_mClass  \
# 0                    org.bewellapp.dashBoardActivity
# 1    com.android.providers.downloads.ui.DownloadList
# 2                     com.android.launcher2.Launcher
# 3  com.android.settings.Settings$SecuritySettings...
# 4  com.google.android.gm.ConversationListActivity...
#
#   RUNNING_TASKS_baseActivity_mPackage  RUNNING_TASKS_id  \
# ...

# %%
u_54=table['RUNNING_TASKS_baseActivity_mPackage'].value_counts()

# %%
u_54
# Out:
# com.android.launcher                                 4404
# com.google.android.apps.paco                         4149
# com.google.android.gm                                3809
# com.android.settings                                 3662
# com.google.android.deskclock                         3386
# com.android.chrome                                   3381
# com.google.android.apps.genie.geniewidget            2576
# com.google.android.talk                              2557
# com.droidhen.fish                                    2340
# com.google.android.googlequicksearchbox              2277
# com.android.systemui                                 2162
# mobi.infolife.uninstaller                            2138
# com.google.android.gallery3d                         1870
# com.google.android.calendar                          1331
# com.android.mms                                       927
# org.bewellapp                                         793
# ...
